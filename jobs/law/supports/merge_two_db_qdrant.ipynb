# %%
import uuid
from loguru import logger
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams, Filter, FieldCondition, PointStruct, MatchValue, FilterSelector, MatchAny


class QdrantStorageManager():
    def __init__(self,
                 host='10.0.0.16', 
                 port=6333):
        self.client = QdrantClient(host=host, port=port, timeout=10)        
        
    def get_type(self) -> str:
        return 'qdrant'
    
    def to_index_struct(self) -> dict:
        return {
            "type": self.get_type(),
            "vector_store": {"class_prefix": self._collection_name}
        }

    def create_collection(self, 
                          collection_name,
                          embedding_size=768):
        self.client.recreate_collection(
            collection_name=collection_name,
            vectors_config=VectorParams(size=embedding_size, 
                                        distance=Distance.COSINE)
        )

# %%
NB_V03_Clauds_dekEmbedding_1_0
NB_V03_Doc_Titles_dekEmbedding_1_0
NB_V03_Sentences_Level_dekEmbedding_1_0_Name

V03_Clauds_dekEmbedding_v1
V03_Doc_Titles_dekEmbedding_v1
V03_Sentences_Level_dekEmbedding_v1_Name
